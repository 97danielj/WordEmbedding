# %%
import re
import urllib.request
import zipfile
from lxml import etree
from nltk.tokenize import word_tokenize, sent_tokenize
from tqdm import tqdm
from glove import Corpus, Glove
# Out:
# ---------------------------------------------------------------------------
# DistutilsPlatformError                    Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyximport.py:214, in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     213         module_name = name
# --> 214     so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
#     215                            inplace=build_inplace, language_level=language_level)
#     216 mod = imp.load_dynamic(name, so_path)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyximport.py:186, in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     185 from . import pyxbuild
# --> 186 so_path = pyxbuild.pyx_to_dll(pyxfilename, extension_mod,
#     187                               build_in_temp=build_in_temp,
#     188                               pyxbuild_dir=pyxbuild_dir,
#     189                               setup_args=sargs,
#     190                               inplace=inplace,
#     191                               reload_support=pyxargs.reload_support)
#     192 assert os.path.exists(so_path), "Cannot find: %s" % so_path
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyxbuild.py:102, in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#     101 obj_build_ext = dist.get_command_obj("build_ext")
# --> 102 dist.run_commands()
#     103 so_path = obj_build_ext.get_outputs()[0]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:967, in Distribution.run_commands(self)
#     966 for cmd in self.commands:
# --> 967     self.run_command(cmd)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\dist.py:1214, in Distribution.run_command(self, command)
#    1211 # Postpone defaults until all explicit configuration is considered
#    1212 # (setup() args, config files, command line and plugins)
# -> 1214 super().run_command(command)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:986, in Distribution.run_command(self, command)
#     985 cmd_obj.ensure_finalized()
# --> 986 cmd_obj.run()
#     987 self.have_run[command] = 1
#
# File C:\ProgramData\Anaconda3\lib\site-packages\Cython\Distutils\old_build_ext.py:186, in old_build_ext.run(self)
#     184     optimization.disable_optimization()
# --> 186 _build_ext.build_ext.run(self)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\command\build_ext.py:339, in build_ext.run(self)
#     338 # Now actually compile and link everything.
# --> 339 self.build_extensions()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\Cython\Distutils\old_build_ext.py:195, in old_build_ext.build_extensions(self)
#     194 # Call original build_extensions
# --> 195 _build_ext.build_ext.build_extensions(self)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\command\build_ext.py:448, in build_ext.build_extensions(self)
#     447 else:
# --> 448     self._build_extensions_serial()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\command\build_ext.py:473, in build_ext._build_extensions_serial(self)
#     472 with self._filter_build_errors(ext):
# --> 473     self.build_extension(ext)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\command\build_ext.py:528, in build_ext.build_extension(self, ext)
#     526     macros.append((undef,))
# --> 528 objects = self.compiler.compile(sources,
#     529                                  output_dir=self.build_temp,
#     530                                  macros=macros,
#     531                                  include_dirs=ext.include_dirs,
#     532                                  debug=self.debug,
#     533                                  extra_postargs=extra_args,
#     534                                  depends=ext.depends)
#     536 # XXX outdated variable, kept here in case third-part code
#     537 # needs it.
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\_msvccompiler.py:327, in MSVCCompiler.compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     326 if not self.initialized:
# --> 327     self.initialize()
#     328 compile_info = self._setup_compile(output_dir, macros, include_dirs,
#     329                                    sources, depends, extra_postargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\_msvccompiler.py:224, in MSVCCompiler.initialize(self, plat_name)
#     222 plat_spec = PLAT_TO_VCVARS[plat_name]
# --> 224 vc_env = _get_vc_env(plat_spec)
#     225 if not vc_env:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\msvc.py:316, in msvc14_get_vc_env(plat_spec)
#     315 try:
# --> 316     return _msvc14_get_vc_env(plat_spec)
#     317 except distutils.errors.DistutilsPlatformError as exc:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\msvc.py:270, in _msvc14_get_vc_env(plat_spec)
#     269 if not vcvarsall:
# --> 270     raise distutils.errors.DistutilsPlatformError(
#     271         "Unable to find vcvarsall.bat"
#     272     )
#     274 try:
#
# DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Input In [1], in <cell line: 7>()
#       5 from nltk.tokenize import word_tokenize, sent_tokenize
#       6 from tqdm import tqdm
# ----> 7 from glove import Corpus, Glove
#
# File ~\AppData\Roaming\Python\Python39\site-packages\glove\__init__.py:1, in <module>
# ----> 1 from .glove import Glove
#       3 __all__ = ["Glove"]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\glove\glove.py:8, in <module>
#       5 import pyximport
#       6 pyximport.install(setup_args={"include_dirs": np.get_include()})
# ----> 8 from .glove_inner import train_glove
#      10 class Glove(object):
#      11     def __init__(self, cooccurence, alpha=0.75, x_max=100.0, d=50, seed=1234):
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyximport.py:459, in PyxLoader.load_module(self, fullname)
#     456     module.__path__ = [self.path]
#     457 else:
#     458     #print "MODULE", fullname
# --> 459     module = load_module(fullname, self.path,
#     460                          self.pyxbuild_dir,
#     461                          build_inplace=self.inplace,
#     462                          language_level=self.language_level)
#     463 return module
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyximport.py:231, in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     228 exc = ImportError("Building module %s failed: %s" % (
#     229     name, traceback.format_exception_only(*sys.exc_info()[:2])))
#     230 if sys.version_info[0] >= 3:
# --> 231     raise exc.with_traceback(tb)
#     232 else:
#     233     exec("raise exc, None, tb", {'exc': exc, 'tb': tb})
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyximport.py:214, in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     212     else:
#     213         module_name = name
# --> 214     so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
#     215                            inplace=build_inplace, language_level=language_level)
#     216 mod = imp.load_dynamic(name, so_path)
#     217 if is_package and not hasattr(mod, '__path__'):
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyximport.py:186, in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     183 build_in_temp = sargs.pop('build_in_temp',build_in_temp)
#     185 from . import pyxbuild
# --> 186 so_path = pyxbuild.pyx_to_dll(pyxfilename, extension_mod,
#     187                               build_in_temp=build_in_temp,
#     188                               pyxbuild_dir=pyxbuild_dir,
#     189                               setup_args=sargs,
#     190                               inplace=inplace,
#     191                               reload_support=pyxargs.reload_support)
#     192 assert os.path.exists(so_path), "Cannot find: %s" % so_path
#     194 junkpath = os.path.join(os.path.dirname(so_path), name+"_*") #very dangerous with --inplace ? yes, indeed, trying to eat my files ;)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pyximport\pyxbuild.py:102, in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#     100 try:
#     101     obj_build_ext = dist.get_command_obj("build_ext")
# --> 102     dist.run_commands()
#     103     so_path = obj_build_ext.get_outputs()[0]
#     104     if obj_build_ext.inplace:
#     105         # Python distutils get_outputs()[ returns a wrong so_path
#     106         # when --inplace ; see http://bugs.python.org/issue5977
#     107         # workaround:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:967, in Distribution.run_commands(self)
#     962 """Run each command that was seen on the setup script command line.
#     963 Uses the list of commands found and cache of command objects
#     964 created by 'get_command_obj()'.
#     965 """
#     966 for cmd in self.commands:
# --> 967     self.run_command(cmd)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\dist.py:1214, in Distribution.run_command(self, command)
#    1210 self.set_defaults()
#    1211 # Postpone defaults until all explicit configuration is considered
#    1212 # (setup() args, config files, command line and plugins)
# -> 1214 super().run_command(command)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:986, in Distribution.run_command(self, command)
#     984 cmd_obj = self.get_command_obj(command)
#     985 cmd_obj.ensure_finalized()
# --> 986 cmd_obj.run()
#     987 self.have_run[command] = 1
#
# File C:\ProgramData\Anaconda3\lib\site-packages\Cython\Distutils\old_build_ext.py:186, in old_build_ext.run(self)
#     182 if self.cython_gdb or [1 for ext in self.extensions
#     183                              if getattr(ext, 'cython_gdb', False)]:
#     184     optimization.disable_optimization()
# --> 186 _build_ext.build_ext.run(self)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\command\build_ext.py:339, in build_ext.run(self)
#     336     self.compiler.set_link_objects(self.link_objects)
#     338 # Now actually compile and link everything.
# --> 339 self.build_extensions()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\Cython\Distutils\old_build_ext.py:195, in old_build_ext.build_extensions(self)
#     193     ext.sources = self.cython_sources(ext.sources, ext)
#     194 # Call original build_extensions
# --> 195 _build_ext.build_ext.build_extensions(self)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\command\build_ext.py:448, in build_ext.build_extensions(self)
#     446     self._build_extensions_parallel()
#     447 else:
# --> 448     self._build_extensions_serial()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\command\build_ext.py:473, in build_ext._build_extensions_serial(self)
#     471 for ext in self.extensions:
#     472     with self._filter_build_errors(ext):
# --> 473         self.build_extension(ext)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\command\build_ext.py:528, in build_ext.build_extension(self, ext)
#     525 for undef in ext.undef_macros:
#     526     macros.append((undef,))
# --> 528 objects = self.compiler.compile(sources,
#     529                                  output_dir=self.build_temp,
#     530                                  macros=macros,
#     531                                  include_dirs=ext.include_dirs,
#     532                                  debug=self.debug,
#     533                                  extra_postargs=extra_args,
#     534                                  depends=ext.depends)
#     536 # XXX outdated variable, kept here in case third-part code
#     537 # needs it.
#     538 self._built_objects = objects[:]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\_msvccompiler.py:327, in MSVCCompiler.compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     322 def compile(self, sources,
#     323             output_dir=None, macros=None, include_dirs=None, debug=0,
#     324             extra_preargs=None, extra_postargs=None, depends=None):
#     326     if not self.initialized:
# --> 327         self.initialize()
#     328     compile_info = self._setup_compile(output_dir, macros, include_dirs,
#     329                                        sources, depends, extra_postargs)
#     330     macros, objects, extra_postargs, pp_opts, build = compile_info
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\_msvccompiler.py:224, in MSVCCompiler.initialize(self, plat_name)
#     221 # Get the vcvarsall.bat spec for the requested platform.
#     222 plat_spec = PLAT_TO_VCVARS[plat_name]
# --> 224 vc_env = _get_vc_env(plat_spec)
#     225 if not vc_env:
#     226     raise DistutilsPlatformError("Unable to find a compatible "
#     227         "Visual Studio installation.")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\msvc.py:316, in msvc14_get_vc_env(plat_spec)
#     314 # Always use backport from CPython 3.8
#     315 try:
# --> 316     return _msvc14_get_vc_env(plat_spec)
#     317 except distutils.errors.DistutilsPlatformError as exc:
#     318     _augment_exception(exc, 14.0)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\setuptools\msvc.py:270, in _msvc14_get_vc_env(plat_spec)
#     268 vcvarsall, vcruntime = _msvc14_find_vcvarsall(plat_spec)
#     269 if not vcvarsall:
# --> 270     raise distutils.errors.DistutilsPlatformError(
#     271         "Unable to find vcvarsall.bat"
#     272     )
#     274 try:
#     275     out = subprocess.check_output(
#     276         'cmd /u /c "{}" {} && set'.format(vcvarsall, plat_spec),
#     277         stderr=subprocess.STDOUT,
#     278     ).decode('utf-16le', errors='replace')
#
# ImportError: Building module glove.glove_inner failed: ['distutils.errors.DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/\n']

# %%
targetXML = open('ted_en-20160408.xml', 'r', encoding='UTF8')
target_text = etree.parse(targetXML)

# xml 파일로부터 <content>와 </content> 사이의 내용만 가져온다.
parse_text = '\n'.join(target_text.xpath('//content/text()'))

# 정규 표현식의 sub 모듈을 통해 content 중간에 등장하는 (Audio), (Laughter) 등의 배경음 부분을 제거.
# 해당 코드는 괄호로 구성된 내용을 제거.
content_text = re.sub(r'\([^)]*\)', '', parse_text)

# 입력 코퍼스에 대해서 NLTK를 이용하여 문장 토큰화를 수행.
sent_text = sent_tokenize(content_text)

# 각 문장에 대해서 구두점을 제거하고, 대문자를 소문자로 변환.
normalized_text = []
for string in tqdm(sent_text):
     tokens = re.sub(r"[^a-z0-9]+", " ", string.lower())
     normalized_text.append(tokens)

# 각 문장에 대해서 NLTK를 이용하여 단어 토큰화를 수행.
result = [word_tokenize(sentence) for sentence in normalized_text]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 12>()
#       9 content_text = re.sub(r'\([^)]*\)', '', parse_text)
#      11 # 입력 코퍼스에 대해서 NLTK를 이용하여 문장 토큰화를 수행.
# ---> 12 sent_text = sent_tokenize(content_text)
#      14 # 각 문장에 대해서 구두점을 제거하고, 대문자를 소문자로 변환.
#      15 normalized_text = []
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py:107, in sent_tokenize(text, language)
#      97 """
#      98 Return a sentence-tokenized copy of *text*,
#      99 using NLTK's recommended sentence tokenizer
#    (...)
#     104 :param language: the model name in the Punkt corpus
#     105 """
#     106 tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107 return tokenizer.tokenize(text)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1276, in PunktSentenceTokenizer.tokenize(self, text, realign_boundaries)
#    1272 def tokenize(self, text, realign_boundaries=True):
#    1273     """
#    1274     Given a text, returns a list of the sentences in that text.
#    1275     """
# -> 1276     return list(self.sentences_from_text(text, realign_boundaries))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1332, in PunktSentenceTokenizer.sentences_from_text(self, text, realign_boundaries)
#    1325 def sentences_from_text(self, text, realign_boundaries=True):
#    1326     """
#    1327     Given a text, generates the sentences in that text by only
#    1328     testing candidate sentence breaks. If realign_boundaries is
#    1329     True, includes in the sentence closing punctuation that
#    1330     follows the period.
#    1331     """
# -> 1332     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1332, in <listcomp>(.0)
#    1325 def sentences_from_text(self, text, realign_boundaries=True):
#    1326     """
#    1327     Given a text, generates the sentences in that text by only
#    1328     testing candidate sentence breaks. If realign_boundaries is
#    1329     True, includes in the sentence closing punctuation that
#    1330     follows the period.
#    1331     """
# -> 1332     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1322, in PunktSentenceTokenizer.span_tokenize(self, text, realign_boundaries)
#    1320 if realign_boundaries:
#    1321     slices = self._realign_boundaries(text, slices)
# -> 1322 for sentence in slices:
#    1323     yield (sentence.start, sentence.stop)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1421, in PunktSentenceTokenizer._realign_boundaries(self, text, slices)
#    1408 """
#    1409 Attempts to realign punctuation that falls after the period but
#    1410 should otherwise be included in the same sentence.
#    (...)
#    1418     ["(Sent1.)", "Sent2."].
#    1419 """
#    1420 realign = 0
# -> 1421 for sentence1, sentence2 in _pair_iter(slices):
#    1422     sentence1 = slice(sentence1.start + realign, sentence1.stop)
#    1423     if not sentence2:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py:318, in _pair_iter(iterator)
#     316 iterator = iter(iterator)
#     317 try:
# --> 318     prev = next(iterator)
#     319 except StopIteration:
#     320     return
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1395, in PunktSentenceTokenizer._slices_from_text(self, text)
#    1393 def _slices_from_text(self, text):
#    1394     last_break = 0
# -> 1395     for match, context in self._match_potential_end_contexts(text):
#    1396         if self.text_contains_sentbreak(context):
#    1397             yield slice(last_break, match.end())
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1381, in PunktSentenceTokenizer._match_potential_end_contexts(self, text)
#    1379 # Find the word before the current match
#    1380 split = text[: match.start()].rsplit(maxsplit=1)
# -> 1381 before_start = len(split[0]) if len(split) == 2 else 0
#    1382 before_words[match] = split[-1] if split else ""
#    1383 matches.append(match)
#
# KeyboardInterrupt:

# %%
import sys

print("--sys.version—")
print(sys.version)
# Out:
# --sys.version—
# 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]

# %%
# !python --version
# Out:
# Python 3.9.12
